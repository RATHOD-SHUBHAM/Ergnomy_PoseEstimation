# %%
import cv2
import mediapipe as mp
import numpy as np

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_pose = mp.solutions.pose

# %%
class Ergonomy:
    def __init__(self):
        self.trunk_angle=0

    def update_joints(self, landmarks_3d):
        """update all needed joints based on landmarks_3d.landmark from mp"""
        try:
            # media pipe joints (BlazePose GHUM 3D)
            left_shoulder = np.array([landmarks_3d.landmark[11].x, landmarks_3d.landmark[11].y, landmarks_3d.landmark[11].z])
            right_shoulder = np.array([landmarks_3d.landmark[12].x, landmarks_3d.landmark[12].y, landmarks_3d.landmark[12].z])
            left_hip = np.array([landmarks_3d.landmark[23].x, landmarks_3d.landmark[23].y, landmarks_3d.landmark[23].z])
            right_hip = np.array([landmarks_3d.landmark[24].x, landmarks_3d.landmark[24].y, landmarks_3d.landmark[24].z])
            left_knee = np.array([landmarks_3d.landmark[25].x, landmarks_3d.landmark[25].y, landmarks_3d.landmark[25].z])
            right_knee = np.array([landmarks_3d.landmark[26].x, landmarks_3d.landmark[26].y, landmarks_3d.landmark[26].z])

            # helper joints
            mid_shoulder = (left_shoulder + right_shoulder) / 2
            mid_hip = (left_hip + right_hip) / 2
            mid_knee = (left_knee + right_knee) / 2

            # angles
            self.trunk_angle = self.get_angle(mid_knee, mid_hip, mid_shoulder, mid_hip, adjust=True)

        except:
            # could not retrieve all needed joints
            pass

    def get_angle(self, a, b, c, d, adjust):
        """return the angle between two vectors"""
        vec1 = a - b
        vec2 = c - d

        cosine_angle = np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))
        angle = np.arccos(cosine_angle)

        # adjust by substracting 180 deg if needed 
        # this lets the angle start at 0 instead of 180
        if (adjust):
            angle_adjusted = abs(np.degrees(angle) - 180)
            return int(angle_adjusted)
        else:
            return int(abs(np.degrees(angle)))

    def get_trunk_color(self):
        """returns (B,G,R) colors for visualization"""
        if self.trunk_angle < 20:
            return (0,255,0)
        elif self.trunk_angle <= 60:
            return (0,255,255)
        else:
            return (0,0,255)

# %%
if __name__ == '__main__':
    MyErgonomy = Ergonomy()
    # cap = cv2.VideoCapture(0)  # webcam input
    cap = cv2.VideoCapture('Input/Animation.mp4')  # custom input
    
    # write to output folder
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    name = "Output/badPostureOutput.mp4"
    videoWidth = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    videoHeight = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    size = (videoWidth, videoHeight) # this should match exactly to output frame
    out = cv2.VideoWriter(name,fourcc, 20, size)
    
    with mp_pose.Pose( model_complexity = 1, smooth_landmarks=True, min_detection_confidence=0.3, min_tracking_confidence=0.3) as pose:
        while cap.isOpened():
            success, image = cap.read()
            
            if not success:
                print("Ignoring empty camera frame.")
                # If loading a video, use 'break' instead of 'continue'.
                break

            # To improve performance, optionally mark the image as not writeable to
            # pass by reference.
            image.flags.writeable = False
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            results = pose.process(image)
            landmarks_3d = results.pose_world_landmarks

            # Draw the pose annotation on the image.
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style())


            MyErgonomy.update_joints(landmarks_3d)
            print("MyErgonomy.trunk_angle : ", MyErgonomy.trunk_angle)

            # visualization: text + HP bar
            image = cv2.putText(image, 
                                text = "trunk angle: " + str(MyErgonomy.trunk_angle), 
                                org = (5,60), 
                                fontFace = cv2.FONT_HERSHEY_SIMPLEX, 
                                fontScale = 1, 
                                color = MyErgonomy.get_trunk_color(), 
                                thickness = 3)
            
            image = cv2.rectangle(image, (5,5), (145*2, 30), color=(255,255,255), thickness=-1)
            image = cv2.rectangle(image, (5,5), (145*2-(MyErgonomy.trunk_angle * 2), 30), color = MyErgonomy.get_trunk_color(), thickness=-1)

            cv2.imshow('MediaPipe Pose Demo', image)
            out.write(image)

            if cv2.waitKey(1) & 0xFF == 27:
                break
    
    
    cap.release()
    out.release()
    
    cv2.destroyAllWindows()
    cv2.waitKey(1)
# Out:
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  3
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  20
# MyErgonomy.trunk_angle :  24
# MyErgonomy.trunk_angle :  23
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  25
# MyErgonomy.trunk_angle :  34
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  47
# MyErgonomy.trunk_angle :  46
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  40
# MyErgonomy.trunk_angle :  53
# MyErgonomy.trunk_angle :  86
# MyErgonomy.trunk_angle :  68
# MyErgonomy.trunk_angle :  53
# MyErgonomy.trunk_angle :  60
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  58
# MyErgonomy.trunk_angle :  54
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  36
# MyErgonomy.trunk_angle :  34
# MyErgonomy.trunk_angle :  36
# MyErgonomy.trunk_angle :  38
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  45
# MyErgonomy.trunk_angle :  64
# MyErgonomy.trunk_angle :  69
# MyErgonomy.trunk_angle :  78
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  86
# MyErgonomy.trunk_angle :  85
# MyErgonomy.trunk_angle :  89
# MyErgonomy.trunk_angle :  91
# MyErgonomy.trunk_angle :  88
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  85
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  83
# MyErgonomy.trunk_angle :  81
# MyErgonomy.trunk_angle :  81
# MyErgonomy.trunk_angle :  82
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  86
# MyErgonomy.trunk_angle :  90
# MyErgonomy.trunk_angle :  91
# MyErgonomy.trunk_angle :  93
# MyErgonomy.trunk_angle :  91
# MyErgonomy.trunk_angle :  91
# MyErgonomy.trunk_angle :  93
# MyErgonomy.trunk_angle :  91
# MyErgonomy.trunk_angle :  89
# MyErgonomy.trunk_angle :  91
# MyErgonomy.trunk_angle :  92
# MyErgonomy.trunk_angle :  93
# MyErgonomy.trunk_angle :  92
# MyErgonomy.trunk_angle :  97
# MyErgonomy.trunk_angle :  95
# MyErgonomy.trunk_angle :  96
# MyErgonomy.trunk_angle :  99
# MyErgonomy.trunk_angle :  101
# MyErgonomy.trunk_angle :  102
# MyErgonomy.trunk_angle :  116
# MyErgonomy.trunk_angle :  106
# MyErgonomy.trunk_angle :  107
# MyErgonomy.trunk_angle :  106
# MyErgonomy.trunk_angle :  94
# MyErgonomy.trunk_angle :  90
# MyErgonomy.trunk_angle :  92
# MyErgonomy.trunk_angle :  87
# MyErgonomy.trunk_angle :  69
# MyErgonomy.trunk_angle :  47
# MyErgonomy.trunk_angle :  49
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  50
# MyErgonomy.trunk_angle :  48
# MyErgonomy.trunk_angle :  62
# MyErgonomy.trunk_angle :  61
# MyErgonomy.trunk_angle :  55
# MyErgonomy.trunk_angle :  44
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  44
# MyErgonomy.trunk_angle :  45
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  44
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  34
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  49
# MyErgonomy.trunk_angle :  58
# MyErgonomy.trunk_angle :  71
# MyErgonomy.trunk_angle :  71
# MyErgonomy.trunk_angle :  96
# MyErgonomy.trunk_angle :  96
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  81
# MyErgonomy.trunk_angle :  82
# MyErgonomy.trunk_angle :  82
# MyErgonomy.trunk_angle :  77
# MyErgonomy.trunk_angle :  82
# MyErgonomy.trunk_angle :  88
# MyErgonomy.trunk_angle :  88
# MyErgonomy.trunk_angle :  78
# MyErgonomy.trunk_angle :  60
# MyErgonomy.trunk_angle :  57
# MyErgonomy.trunk_angle :  68
# MyErgonomy.trunk_angle :  94
# MyErgonomy.trunk_angle :  89
# MyErgonomy.trunk_angle :  86
# MyErgonomy.trunk_angle :  83
# MyErgonomy.trunk_angle :  83
# MyErgonomy.trunk_angle :  103
# MyErgonomy.trunk_angle :  101
# MyErgonomy.trunk_angle :  92
# MyErgonomy.trunk_angle :  84
# MyErgonomy.trunk_angle :  87
# MyErgonomy.trunk_angle :  88
# MyErgonomy.trunk_angle :  87
# MyErgonomy.trunk_angle :  86
# MyErgonomy.trunk_angle :  87
# MyErgonomy.trunk_angle :  94
# MyErgonomy.trunk_angle :  97
# MyErgonomy.trunk_angle :  87
# MyErgonomy.trunk_angle :  80
# MyErgonomy.trunk_angle :  69
# MyErgonomy.trunk_angle :  57
# MyErgonomy.trunk_angle :  60
# MyErgonomy.trunk_angle :  50
# MyErgonomy.trunk_angle :  32
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  29
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  25
# MyErgonomy.trunk_angle :  25
# MyErgonomy.trunk_angle :  26
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  29
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  32
# MyErgonomy.trunk_angle :  38
# MyErgonomy.trunk_angle :  38
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  36
# MyErgonomy.trunk_angle :  32
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  24
# MyErgonomy.trunk_angle :  20
# MyErgonomy.trunk_angle :  23
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  40
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  38
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  28
# MyErgonomy.trunk_angle :  24
# MyErgonomy.trunk_angle :  21
# MyErgonomy.trunk_angle :  20
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  24
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  20
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  37
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  37
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  32
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  23
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  20
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  21
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  22
# MyErgonomy.trunk_angle :  29
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  31
# MyErgonomy.trunk_angle :  67
# MyErgonomy.trunk_angle :  66
# MyErgonomy.trunk_angle :  70
# MyErgonomy.trunk_angle :  82
# MyErgonomy.trunk_angle :  76
# MyErgonomy.trunk_angle :  81
# MyErgonomy.trunk_angle :  78
# MyErgonomy.trunk_angle :  62
# MyErgonomy.trunk_angle :  44
# MyErgonomy.trunk_angle :  49
# MyErgonomy.trunk_angle :  59
# MyErgonomy.trunk_angle :  38
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  45
# MyErgonomy.trunk_angle :  35
# MyErgonomy.trunk_angle :  26
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  20
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  2
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  26
# MyErgonomy.trunk_angle :  29
# MyErgonomy.trunk_angle :  38
# MyErgonomy.trunk_angle :  32
# MyErgonomy.trunk_angle :  6
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  78
# MyErgonomy.trunk_angle :  153
# MyErgonomy.trunk_angle :  155
# MyErgonomy.trunk_angle :  150
# MyErgonomy.trunk_angle :  127
# MyErgonomy.trunk_angle :  108
# MyErgonomy.trunk_angle :  131
# MyErgonomy.trunk_angle :  118
# MyErgonomy.trunk_angle :  68
# MyErgonomy.trunk_angle :  64
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  27
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  26
# MyErgonomy.trunk_angle :  21
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  21
# MyErgonomy.trunk_angle :  23
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  30
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  37
# MyErgonomy.trunk_angle :  40
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  45
# MyErgonomy.trunk_angle :  47
# MyErgonomy.trunk_angle :  45
# MyErgonomy.trunk_angle :  44
# MyErgonomy.trunk_angle :  43
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  42
# MyErgonomy.trunk_angle :  41
# MyErgonomy.trunk_angle :  39
# MyErgonomy.trunk_angle :  36
# MyErgonomy.trunk_angle :  34
# MyErgonomy.trunk_angle :  33
# MyErgonomy.trunk_angle :  25
# MyErgonomy.trunk_angle :  21
# MyErgonomy.trunk_angle :  22
# MyErgonomy.trunk_angle :  24
# MyErgonomy.trunk_angle :  24
# MyErgonomy.trunk_angle :  25
# MyErgonomy.trunk_angle :  32
# MyErgonomy.trunk_angle :  44
# MyErgonomy.trunk_angle :  46
# MyErgonomy.trunk_angle :  38
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  1
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  19
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  13
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  16
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  14
# MyErgonomy.trunk_angle :  15
# MyErgonomy.trunk_angle :  17
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  18
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  1
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  4
# MyErgonomy.trunk_angle :  5
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  7
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  12
# MyErgonomy.trunk_angle :  11
# MyErgonomy.trunk_angle :  10
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  9
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# MyErgonomy.trunk_angle :  8
# Ignoring empty camera frame.
